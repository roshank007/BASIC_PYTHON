# %%
#ROSHAN KALYANI

# %% [markdown]
# # WINDOWS 11
# # ANACONDA 2.1.1
# # PYTHON 3.10

# %%
#!pip3 install gTTS

# %%
#IMPORTING LIBRARIES 
from gtts import gTTS
import os

# %%
#DEFINE THE LANGUAGE AND ASSIGNING FILE INTO VARIABLE
audio = 'speech.mp3'
language = 'en'

# %%
#CALLING gTTS, here can replace text with your text.
sp = gTTS(text = 'Welcome to python',
         lang = language,
         slow  = False)
sp.save(audio)

# %%
os.system(audio)
# Out:
# 0

# %% [markdown]
# ## YOUR OUTPUT WILL LOOK ALIKE 👍

# %% [markdown]
# ![text_to_speech.jpg](attachment:text_to_speech.jpg)
